# %% [markdown]
# # Clean lexique dataset to build word frequency dataset
#
# The Lexique383 dataset is a French word frequency (books and movies subtitles) dataset. It contains 140,000+ words with many different informations about pronounciation, lemme, genre etc. which we do not care about. We then have to filter the dataset to only keep single words without any special characters, normalize them to remove accents and group them by orthograph to have the real frequency.

# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd

# %% [markdown]
# ## Loading raw dataset

# %%
pd.set_option('display.max_columns', None)
lexique_df = pd.read_excel("Lexique383.xlsb")
lexique_df.head()
# Out:
#       1_ortho   2_phon     3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 0           a        a           a     NOM       m      NaN            81.36
# 1           a        a       avoir     AUX     NaN      NaN         18559.22
# 2           a        a       avoir     VER     NaN      NaN         13572.40
# 3   a capella  akapEla   a capella     ADV     NaN      NaN             0.04
# 4  a cappella  akapEla  a cappella     ADV     NaN      NaN             0.04
#
#    8_freqlemlivres  9_freqfilms2  10_freqlivres   11_infover  12_nbhomogr  \
# 0            58.65         81.36          58.65          NaN            3
# 1         12800.81       6350.91        2926.69  ind:pre:3s;            3
# 2          6426.49       5498.34        1669.39  ind:pre:3s;            3
# 3             0.07          0.04           0.07          NaN            1
# 4             0.07          0.04           0.07          NaN            1
#
#    13_nbhomoph  14_islem  15_nblettres  16_nbphons     17_cvcv 18_p_cvcv  \
# 0            9         1             1           1           V         V
# 1            9         0             1           1           V         V
# 2            9         0             1           1           V         V
# 3            2         1             9           7   V CVCVCCV   VCVCVCV
# 4            2         1            10           7  V CVCCVCCV   VCVCVCV
#
#    19_voisorth  20_voisphon  21_puorth  22_puphon     23_syll  24_nbsyll  \
# 0           25           20          1          1           a          1
# 1           25           20          1          1           a          1
# 2           25           20          1          1           a          1
# 3            0            0          6          5  a-ka-pE-la          4
# 4            0            0          6          5  a-ka-pE-la          4
#
#      25_cv-cv 26_orthrenv 27_phonrenv  28_orthosyll 29_cgramortho  30_deflem  \
# 0           V           a           a             a   NOM,AUX,VER        NaN
# 1           V           a           a             a   NOM,AUX,VER        NaN
# 2           V           a           a             a   NOM,AUX,VER       93.0
# 3  V-CV-CV-CV   allepac a     alEpaka   a ca-pel-la           ADV        NaN
# 4  V-CV-CV-CV  alleppac a     alEpaka  a cap-pel-la           ADV        NaN
#
#    31_defobs  32_old20  33_pld20 34_morphoder  35_nbmorph
# 0        NaN      1.00      1.00            a           1
# 1        NaN      1.00      1.00        avoir           1
# 2       16.0      1.00      1.00        avoir           1
# 3        NaN      3.85      2.85    a-capella           2
# 4        NaN      4.60      2.85   a-cappella           2

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Dataset size

# %%
lexique_df["3_lemme"].unique().shape
# Out:
# (46947,)

# %% [markdown]
# ### Data consistency

# %% [markdown]
# The length of the word should match the length of the string.

# %%
# Check if the length of the string in "1_ortho" column is equal to the column "15_nblettres"
print(lexique_df["1_ortho"].str.len().equals(lexique_df["15_nblettres"]))
# Out:
# False

# %% [markdown]
# ### Some words were interpreted

# %% [markdown]
# Here are the words not corresponding to their length

# %%
nblettres_diff_df = lexique_df[lexique_df["1_ortho"].str.len() != (lexique_df["15_nblettres"])][["1_ortho", "15_nblettres"]]
nblettres_diff_df
# Out:
#        1_ortho  15_nblettres
# 55603    False             4
# 55604    False             4
# 55605    False             4
# 86569      NaN             3
# 136832    True             4
# 136833    True             4

# %% [markdown]
# The data seems clean anyways, it looks like it is an interpretation issue

# %%
nblettres_diff_idx = nblettres_diff_df.index
display(lexique_df.iloc[nblettres_diff_idx])
# Out:
#        1_ortho 2_phon 3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 55603    False     fo   False     ADJ       m      NaN           122.23
# 55604    False     fo   False     ADV     NaN      NaN             7.61
# 55605    False     fo   False     NOM     NaN      NaN             5.71
# 86569      NaN     n@     NaN     NOM       m        s            11.92
# 136832    True    vRE    True     ADJ       m        s           807.03
# 136833    True    vRE    True     NOM       m        s            37.58
#
#         8_freqlemlivres  9_freqfilms2  10_freqlivres 11_infover  12_nbhomogr  \
# 55603            109.59         90.99          66.55        NaN            3
# 55604              2.70          7.61           2.70        NaN            3
# 55605              8.51          5.71           8.51        NaN            3
# 86569              1.42         11.92           1.42        NaN            1
# 136832           430.07        678.47         311.89        NaN            2
# 136833            37.77         34.59          32.70        NaN            2
#
#         13_nbhomoph  14_islem  15_nblettres  16_nbphons 17_cvcv 18_p_cvcv  \
# 55603             5         1             4           2    CVVC        CV
# 55604             5         1             4           2    CVVC        CV
# 55605             5         1             4           2    CVVC        CV
# 86569             2         1             3           2     CVC        CV
# 136832            6         1             4           3    CCVV       CCV
# 136833            6         1             4           3    CCVV       CCV
#
#         19_voisorth  20_voisphon  21_puorth  22_puphon 23_syll  24_nbsyll  \
# 55603             9           23          4          2      fo          1
# 55604             9           23          4          2      fo          1
# 55605             9           23          4          2      fo          1
# 86569            14           28          3          2      n@          1
# 136832            4           12          4          3     vRE          1
# 136833            4           12          4          3     vRE          1
#
#        25_cv-cv 26_orthrenv 27_phonrenv 28_orthosyll 29_cgramortho  30_deflem  \
# 55603        CV        xuaf          of        False   ADJ,ADV,NOM      100.0
# 55604        CV        xuaf          of        False   ADJ,ADV,NOM        NaN
# 55605        CV        xuaf          of        False   ADJ,ADV,NOM      100.0
# 86569        CV         NaN          @n          NaN           NOM        NaN
# 136832      CCV        iarv         ERv         True       ADJ,NOM       95.0
# 136833      CCV        iarv         ERv         True       ADJ,NOM       94.0
#
#         31_defobs  32_old20  33_pld20 34_morphoder  35_nbmorph
# 55603        20.0      1.35       1.0        False           1
# 55604         NaN      1.35       1.0        False           1
# 55605        23.0      1.35       1.0        False           1
# 86569         NaN      1.00       1.0          NaN           1
# 136832       21.0      1.60       1.0         True           1
# 136833       17.0      1.60       1.0         True           1

# %% [markdown]
# Changing the values to the corresponding raw strings

# %%
lexique_df["1_ortho"] = lexique_df["1_ortho"].replace([False, True], ["faux", "vrai"])
lexique_df["1_ortho"] = lexique_df["1_ortho"].fillna("nan")

# %% [markdown]
# Now the length of each word is matching the length of the string

# %%
print(lexique_df["1_ortho"].str.len().equals(lexique_df["15_nblettres"]))
# Out:
# True

# %% [markdown]
# ### Checking all words are in lower case

# %%
min(lexique_df["1_ortho"] == lexique_df["1_ortho"].str.lower())
# Out:
# True

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# We remove the words containing special characters (non word characters)

# %%
lexique_df = lexique_df.loc[lexique_df["1_ortho"].str.match(r"\A[\w]+\Z")]
lexique_df
# Out:
#        1_ortho 2_phon 3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 0            a      a       a     NOM       m      NaN            81.36
# 1            a      a   avoir     AUX     NaN      NaN         18559.22
# 2            a      a   avoir     VER     NaN      NaN         13572.40
# 13          aa     aa      aa     NOM       m        s             0.01
# 17       abaca  abaka   abaca     NOM       m        s             0.01
# ...        ...    ...     ...     ...     ...      ...              ...
# 142689    ôtée    ote     ôté     ADJ       f        s             0.23
# 142690   ôtées    ote    ôter     VER       f        p            16.81
# 142691   ôtées    ote     ôté     ADJ       f        p             0.23
# 142692    ôtés    ote    ôter     VER       m        p            16.81
# 142693    ôtés    ote     ôté     ADJ       m        p             0.23
#
#         8_freqlemlivres  9_freqfilms2  10_freqlivres   11_infover  \
# 0                 58.65         81.36          58.65          NaN
# 1              12800.81       6350.91        2926.69  ind:pre:3s;
# 2               6426.49       5498.34        1669.39  ind:pre:3s;
# 13                 0.00          0.01           0.00          NaN
# 17                 0.00          0.01           0.00          NaN
# ...                 ...           ...            ...          ...
# 142689             0.61          0.10           0.27          NaN
# 142690            42.03          0.16           0.07     par:pas;
# 142691             0.61          0.01           0.07          NaN
# 142692            42.03          0.04           0.14     par:pas;
# 142693             0.61          0.01           0.07          NaN
#
#         12_nbhomogr  13_nbhomoph  14_islem  15_nblettres  16_nbphons 17_cvcv  \
# 0                 3            9         1             1           1       V
# 1                 3            9         0             1           1       V
# 2                 3            9         0             1           1       V
# 13                1            2         1             2           2      VV
# 17                1            1         1             5           5   VCVCV
# ...             ...          ...       ...           ...         ...     ...
# 142689            2           11         0             4           3    VCVV
# 142690            2           11         0             5           3   VCVVC
# 142691            2           11         0             5           3   VCVVC
# 142692            2           11         0             4           3    VCVC
# 142693            2           11         0             4           3    VCVC
#
#        18_p_cvcv  19_voisorth  20_voisphon  21_puorth  22_puphon  23_syll  \
# 0              V           25           20          1          1        a
# 1              V           25           20          1          1        a
# 2              V           25           20          1          1        a
# 13            VV           20           35          2          2      a-a
# 17         VCVCV            0            1          4          5  a-ba-ka
# ...          ...          ...          ...        ...        ...      ...
# 142689       VCV            1           19          0          3     o-te
# 142690       VCV            0           19          0          3     o-te
# 142691       VCV            0           19          0          3     o-te
# 142692       VCV            3           19          0          3     o-te
# 142693       VCV            3           19          0          3     o-te
#
#         24_nbsyll 25_cv-cv 26_orthrenv 27_phonrenv 28_orthosyll 29_cgramortho  \
# 0               1        V           a           a            a   NOM,AUX,VER
# 1               1        V           a           a            a   NOM,AUX,VER
# 2               1        V           a           a            a   NOM,AUX,VER
# 13              2      V-V          aa          aa          NaN           NOM
# 17              3  V-CV-CV       acaba       akaba          NaN           NOM
# ...           ...      ...         ...         ...          ...           ...
# 142689          2     V-CV        eétô         eto        ô-tée       VER,ADJ
# 142690          2     V-CV       seétô         eto       ô-tées       VER,ADJ
# 142691          2     V-CV       seétô         eto       ô-tées       VER,ADJ
# 142692          2     V-CV        sétô         eto        ô-tés       VER,ADJ
# 142693          2     V-CV        sétô         eto        ô-tés       VER,ADJ
#
#         30_deflem  31_defobs  32_old20  33_pld20 34_morphoder  35_nbmorph
# 0             NaN        NaN      1.00       1.0            a           1
# 1             NaN        NaN      1.00       1.0        avoir           1
# 2            93.0       16.0      1.00       1.0        avoir           1
# 13            NaN        NaN      1.00       1.0           aa           1
# 17            NaN        NaN      2.00       1.9        abaca           1
# ...           ...        ...       ...       ...          ...         ...
# 142689        NaN        NaN      1.80       1.0          ôté           1
# 142690       89.0       28.0      1.85       1.0         ôter           1
# 142691        NaN        NaN      1.85       1.0          ôté           1
# 142692       89.0       28.0      1.65       1.0         ôter           1
# 142693        NaN        NaN      1.65       1.0          ôté           1
#
# [137831 rows x 35 columns]

# %% [markdown]
# We remove accents

# %%
lexique_df["1_ortho"] = lexique_df["1_ortho"].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
lexique_df
# Out:
#        1_ortho 2_phon 3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 0            a      a       a     NOM       m      NaN            81.36
# 1            a      a   avoir     AUX     NaN      NaN         18559.22
# 2            a      a   avoir     VER     NaN      NaN         13572.40
# 13          aa     aa      aa     NOM       m        s             0.01
# 17       abaca  abaka   abaca     NOM       m        s             0.01
# ...        ...    ...     ...     ...     ...      ...              ...
# 142689    otee    ote     ôté     ADJ       f        s             0.23
# 142690   otees    ote    ôter     VER       f        p            16.81
# 142691   otees    ote     ôté     ADJ       f        p             0.23
# 142692    otes    ote    ôter     VER       m        p            16.81
# 142693    otes    ote     ôté     ADJ       m        p             0.23
#
#         8_freqlemlivres  9_freqfilms2  10_freqlivres   11_infover  \
# 0                 58.65         81.36          58.65          NaN
# 1              12800.81       6350.91        2926.69  ind:pre:3s;
# 2               6426.49       5498.34        1669.39  ind:pre:3s;
# 13                 0.00          0.01           0.00          NaN
# 17                 0.00          0.01           0.00          NaN
# ...                 ...           ...            ...          ...
# 142689             0.61          0.10           0.27          NaN
# 142690            42.03          0.16           0.07     par:pas;
# 142691             0.61          0.01           0.07          NaN
# 142692            42.03          0.04           0.14     par:pas;
# 142693             0.61          0.01           0.07          NaN
#
#         12_nbhomogr  13_nbhomoph  14_islem  15_nblettres  16_nbphons 17_cvcv  \
# 0                 3            9         1             1           1       V
# 1                 3            9         0             1           1       V
# 2                 3            9         0             1           1       V
# 13                1            2         1             2           2      VV
# 17                1            1         1             5           5   VCVCV
# ...             ...          ...       ...           ...         ...     ...
# 142689            2           11         0             4           3    VCVV
# 142690            2           11         0             5           3   VCVVC
# 142691            2           11         0             5           3   VCVVC
# 142692            2           11         0             4           3    VCVC
# 142693            2           11         0             4           3    VCVC
#
#        18_p_cvcv  19_voisorth  20_voisphon  21_puorth  22_puphon  23_syll  \
# 0              V           25           20          1          1        a
# 1              V           25           20          1          1        a
# 2              V           25           20          1          1        a
# 13            VV           20           35          2          2      a-a
# 17         VCVCV            0            1          4          5  a-ba-ka
# ...          ...          ...          ...        ...        ...      ...
# 142689       VCV            1           19          0          3     o-te
# 142690       VCV            0           19          0          3     o-te
# 142691       VCV            0           19          0          3     o-te
# 142692       VCV            3           19          0          3     o-te
# 142693       VCV            3           19          0          3     o-te
#
#         24_nbsyll 25_cv-cv 26_orthrenv 27_phonrenv 28_orthosyll 29_cgramortho  \
# 0               1        V           a           a            a   NOM,AUX,VER
# 1               1        V           a           a            a   NOM,AUX,VER
# 2               1        V           a           a            a   NOM,AUX,VER
# 13              2      V-V          aa          aa          NaN           NOM
# 17              3  V-CV-CV       acaba       akaba          NaN           NOM
# ...           ...      ...         ...         ...          ...           ...
# 142689          2     V-CV        eétô         eto        ô-tée       VER,ADJ
# 142690          2     V-CV       seétô         eto       ô-tées       VER,ADJ
# 142691          2     V-CV       seétô         eto       ô-tées       VER,ADJ
# 142692          2     V-CV        sétô         eto        ô-tés       VER,ADJ
# 142693          2     V-CV        sétô         eto        ô-tés       VER,ADJ
#
#         30_deflem  31_defobs  32_old20  33_pld20 34_morphoder  35_nbmorph
# 0             NaN        NaN      1.00       1.0            a           1
# 1             NaN        NaN      1.00       1.0        avoir           1
# 2            93.0       16.0      1.00       1.0        avoir           1
# 13            NaN        NaN      1.00       1.0           aa           1
# 17            NaN        NaN      2.00       1.9        abaca           1
# ...           ...        ...       ...       ...          ...         ...
# 142689        NaN        NaN      1.80       1.0          ôté           1
# 142690       89.0       28.0      1.85       1.0         ôter           1
# 142691        NaN        NaN      1.85       1.0          ôté           1
# 142692       89.0       28.0      1.65       1.0         ôter           1
# 142693        NaN        NaN      1.65       1.0          ôté           1
#
# [137831 rows x 35 columns]

# %% [markdown]
# Then we group by ortograph and sum over frequency

# %%
# Group by "1_ortho" column and sum over the "10_freqlivres" column
groupped_nblettres = lexique_df[["1_ortho", "15_nblettres"]].groupby("1_ortho").first().reset_index()
groupped_frequency = lexique_df[["1_ortho", "10_freqlivres"]].groupby("1_ortho").sum().reset_index()
word_frequency_df = pd.merge(groupped_nblettres, groupped_frequency, on="1_ortho")
word_frequency_df.head()
# Out:
#     1_ortho  15_nblettres  10_freqlivres
# 0         a             1       23863.78
# 1        aa             2           0.00
# 2     abaca             5           0.00
# 3   abaissa             7           2.64
# 4  abaissai             8           0.07

# %%
word_frequency_df[word_frequency_df["10_freqlivres"] == 0.0].shape[0]/word_frequency_df.shape[0]
# Out:
# 0.14214392634957992

# %%
# Normalize the "10_freqlivres" column
# word_frequency_df["10_freqlivres"] = word_frequency_df["10_freqlivres"] / word_frequency_df["10_freqlivres"].sum()
# word_frequency_df.head()

# %%
os.makedirs("word_frequency_vocab", exist_ok=True)
file_template_path = "word_frequency_vocab/word_frequency_{}.csv"
for nblettres in word_frequency_df["15_nblettres"].unique():
    nblettres_word_frequency = word_frequency_df.loc[word_frequency_df["15_nblettres"] == nblettres]
    nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
    nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
    nblettres_word_frequency.to_csv(file_template_path.format(nblettres), index=False)
# Out:
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.drop(columns=["15_nblettres"], inplace=True)
# C:\Users\jerom\AppData\Local\Temp\ipykernel_12484\3625961411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nblettres_word_frequency.rename(columns={"1_ortho": "word", "10_freqlivres": "frequency"}, inplace=True)
